# %%
 # %%writefile auth.log
 Sep  3 02:14:19 webserver01 sshd[1122]: Failed password for invalid user admin from 203.0.113.45 port 51230 ssh2
Sep  3 02:14:22 webserver01 sshd[1122]: Failed password for invalid user admin from 203.0.113.45 port 51231 ssh2
Sep  3 02:14:25 webserver01 sshd[1122]: Failed password for invalid user root from 203.0.113.45 port 51232 ssh2
Sep  3 02:14:28 webserver01 sshd[1122]: Failed password for invalid user test from 203.0.113.45 port 51233 ssh2
Sep  3 02:14:31 webserver01 sshd[1122]: Failed password for invalid user oracle from 203.0.113.45 port 51234 ssh2
Sep  3 02:14:35 webserver01 sshd[1122]: Failed password for invalid user postgres from 203.0.113.45 port 51235 ssh2
Sep  3 02:14:40 webserver01 sshd[1122]: Failed password for admin from 203.0.113.45 port 51236 ssh2
Sep  3 02:14:44 webserver01 sshd[1122]: Failed password for admin from 203.0.113.45 port 51237 ssh2
Sep  3 02:14:49 webserver01 sshd[1122]: Accepted password for admin from 203.0.113.45 port 51238 ssh2
Sep  3 02:14:50 webserver01 sshd[1122]: pam_unix(sshd:session): session opened for user admin by (uid=0)
Sep  3 09:02:11 webserver01 sshd[2201]: Accepted publickey for anushka from 10.0.0.15 port 60213 ssh2
Sep  3 09:02:11 webserver01 sshd[2201]: pam_unix(sshd:session): session opened for user anushka by (uid=0)
Sep  3 09:15:33 webserver01 sudo:  anushka : TTY=pts/0 ; PWD=/home/anushka ; USER=root ; COMMAND=/bin/systemctl restart nginx
Sep  3 10:44:02 webserver01 sshd[2340]: Accepted publickey for devops from 10.0.0.22 port 55210 ssh2
Sep  3 10:44:02 webserver01 sshd[2340]: pam_unix(sshd:session): session opened for user devops by (uid=0)
Sep  3 11:20:19 webserver01 sshd[2340]: pam_unix(sshd:session): session closed for user devops
Sep  3 13:05:44 webserver01 sshd[2501]: Accepted publickey for anushka from 10.0.0.15 port 60998 ssh2
Sep  3 13:05:44 webserver01 sshd[2501]: pam_unix(sshd:session): session opened for user anushka by (uid=0)
Sep  3 14:30:12 webserver01 sshd[2501]: pam_unix(sshd:session): session closed for user anushka
Sep  3 18:12:07 webserver01 sshd[2890]: Failed password for invalid user ubuntu from 198.51.100.7 port 44210 ssh2
Sep  3 18:12:10 webserver01 sshd[2890]: Failed password for invalid user ubuntu from 198.51.100.7 port 44211 ssh2
Sep  3 18:12:14 webserver01 sshd[2890]: Connection closed by 198.51.100.7 port 44212 [preauth]
Sep  4 03:47:02 webserver01 sshd[3102]: Accepted password for backup_svc from 45.33.22.11 port 39812 ssh2
Sep  4 03:47:02 webserver01 sshd[3102]: pam_unix(sshd:session): session opened for user backup_svc by (uid=0)
Sep  4 03:47:19 webserver01 sudo:  backup_svc : TTY=pts/1 ; PWD=/home/backup_svc ; USER=root ; COMMAND=/usr/sbin/useradd -m -s /bin/bash sysmgr
Sep  4 03:47:33 webserver01 sudo:  backup_svc : TTY=pts/1 ; PWD=/home/backup_svc ; USER=root ; COMMAND=/usr/sbin/usermod -aG sudo sysmgr
Sep  4 03:47:51 webserver01 sudo:  backup_svc : TTY=pts/1 ; PWD=/home/backup_svc ; USER=root ; COMMAND=/bin/passwd sysmgr
Sep  4 03:48:20 webserver01 sshd[3102]: pam_unix(sshd:session): session closed for user backup_svc
Sep  4 08:01:15 webserver01 sshd[3340]: Accepted publickey for anushka from 10.0.0.15 port 61122 ssh2
Sep  4 08:01:15 webserver01 sshd[3340]: pam_unix(sshd:session): session opened for user anushka by (uid=0)
Sep  4 09:30:44 webserver01 sshd[3340]: pam_unix(sshd:session): session closed for user anushka
Sep  4 12:15:09 webserver01 sshd[3550]: Failed password for invalid user admin from 203.0.113.45 port 52011 ssh2
Sep  4 12:15:12 webserver01 sshd[3550]: Failed password for invalid user admin from 203.0.113.45 port 52012 ssh2
Sep  4 12:15:16 webserver01 sshd[3550]: Connection closed by 203.0.113.45 port 52013 [preauth]
# Out:
# Overwriting auth.log

# %%
# !grep "Failed password" auth.log | wc -l
# Out:
# 12

# %%
# !grep "Failed password" auth.log
# Out:
# Sep  3 02:14:19 webserver01 sshd[1122]: Failed password for invalid user admin from 203.0.113.45 port 51230 ssh2
# Sep  3 02:14:22 webserver01 sshd[1122]: Failed password for invalid user admin from 203.0.113.45 port 51231 ssh2
# Sep  3 02:14:25 webserver01 sshd[1122]: Failed password for invalid user root from 203.0.113.45 port 51232 ssh2
# Sep  3 02:14:28 webserver01 sshd[1122]: Failed password for invalid user test from 203.0.113.45 port 51233 ssh2
# Sep  3 02:14:31 webserver01 sshd[1122]: Failed password for invalid user oracle from 203.0.113.45 port 51234 ssh2
# Sep  3 02:14:35 webserver01 sshd[1122]: Failed password for invalid user postgres from 203.0.113.45 port 51235 ssh2
# Sep  3 02:14:40 webserver01 sshd[1122]: Failed password for admin from 203.0.113.45 port 51236 ssh2
# Sep  3 02:14:44 webserver01 sshd[1122]: Failed password for admin from 203.0.113.45 port 51237 ssh2
# ...

# %%
# !grep "Accepted" auth.log
# Out:
# Sep  3 02:14:49 webserver01 sshd[1122]: Accepted password for admin from 203.0.113.45 port 51238 ssh2
# Sep  3 09:02:11 webserver01 sshd[2201]: Accepted publickey for anushka from 10.0.0.15 port 60213 ssh2
# Sep  3 10:44:02 webserver01 sshd[2340]: Accepted publickey for devops from 10.0.0.22 port 55210 ssh2
# Sep  3 13:05:44 webserver01 sshd[2501]: Accepted publickey for anushka from 10.0.0.15 port 60998 ssh2
# Sep  4 03:47:02 webserver01 sshd[3102]: Accepted password for backup_svc from 45.33.22.11 port 39812 ssh2
# Sep  4 08:01:15 webserver01 sshd[3340]: Accepted publickey for anushka from 10.0.0.15 port 61122 ssh2

# %%
# !grep "sudo" auth.log
# Out:
# Sep  3 09:15:33 webserver01 sudo:  anushka : TTY=pts/0 ; PWD=/home/anushka ; USER=root ; COMMAND=/bin/systemctl restart nginx
# Sep  4 03:47:19 webserver01 sudo:  backup_svc : TTY=pts/1 ; PWD=/home/backup_svc ; USER=root ; COMMAND=/usr/sbin/useradd -m -s /bin/bash sysmgr
# Sep  4 03:47:33 webserver01 sudo:  backup_svc : TTY=pts/1 ; PWD=/home/backup_svc ; USER=root ; COMMAND=/usr/sbin/usermod -aG sudo sysmgr
# Sep  4 03:47:51 webserver01 sudo:  backup_svc : TTY=pts/1 ; PWD=/home/backup_svc ; USER=root ; COMMAND=/bin/passwd sysmgr
